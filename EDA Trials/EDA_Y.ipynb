# %%
import numpy as np 
import pandas as pd
import math
import seaborn as sns
import matplotlib.pyplot as plt
covid_data = pd.read_csv('data.csv')

# %%
covid_data.columns
# Out:
# Index(['Unnamed: 0', 'county', 'new_positives',
#        'cumulative_number_of_positives', 'total_number_of_tests_performed',
#        'cumulative_number_of_tests_performed', 'date', 'retail_and_recreation',
#        'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces',
#        'residential'],
#       dtype='object')

# %%
covid_data = covid_data.drop(['Unnamed: 0'],axis=1)

# %%
sns.scatterplot(x=covid_data['new_positives'].dropna(), y=covid_data['parks'].dropna())
plt.title('New positives vs Parks Mobility')
# Out:
# Text(0.5, 1.0, 'New positives vs Parks Mobility')

# %%
sns.scatterplot(x=covid_data['new_positives'].dropna(), y=covid_data['retail_and_recreation'].dropna())
plt.title('New positives vs Retail and Recreation Mobility')
# Out:
# Text(0.5, 1.0, 'New positives vs Retail and Recreation Mobility')

# %%
sns.scatterplot(x=covid_data['new_positives'].dropna(), y=covid_data['grocery_and_pharmacy'].dropna())
plt.title('New positives vs Grocery and Pharmacy Mobility')
# Out:
# Text(0.5, 1.0, 'New positives vs Grocery and Pharmacy Mobility')

# %%
sns.scatterplot(x=covid_data['new_positives'].dropna(), y=covid_data['transit_stations'].dropna())
plt.title('New positives vs Transit Stations Mobility')
# Out:
# Text(0.5, 1.0, 'New positives vs Transit Stations Mobility')

# %%
sns.scatterplot(x=covid_data['new_positives'].dropna(), y=covid_data['workplaces'].dropna())
plt.title('New positives vs Workplaces Mobility')
# Out:
# Text(0.5, 1.0, 'New positives vs Workplaces Mobility')

# %%
sns.scatterplot(x=covid_data['new_positives'].dropna(), y=covid_data['residential'].dropna())
plt.title('New positives vs residential Mobility')
# Out:
# Text(0.5, 1.0, 'New positives vs residential Mobility')
